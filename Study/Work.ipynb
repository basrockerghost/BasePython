# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf

data=pd.read_csv(r'C:\Users\User\Downloads\data (1).csv')
# data.isnull().sum()
data.dropna(inplace=True)
X=data['Pulse']
y=data['Calories']

slope, intercept, r, p, std_err = stats.linregress(X,y)

def myfunc(x):
    return slope*x+intercept

mymodel = list(map(myfunc, X))
plt.scatter(X,y, color='gray')
plt.plot(X, mymodel, color='blue', label="Fitted line")
plt.ylim(ymin=0, ymax=2000)
plt.xlim(xmin=0, xmax=200)
plt.xlabel("Pulse")
plt.ylabel("Calories")
plt.show()
print('intercept : '+str(intercept))
print('slope : '+str(slope))
print('Relation : '+str(r))
# Out:
# intercept : 326.5641323156726
# slope : 0.45716531514976466
# Relation : 0.025121130626710286

# %%
import statsmodels.formula.api as smf

data=pd.read_csv(r'C:\Users\User\Downloads\data (1).csv')
model=smf.ols('Calories ~ Pulse', data = data)
result=model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               Calories   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.1023
# Date:                Tue, 07 Nov 2023   Prob (F-statistic):              0.750
# Time:                        09:49:55   Log-Likelihood:                -1148.1
# No. Observations:                 164   AIC:                             2300.
# Df Residuals:                     162   BIC:                             2306.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    326.5641    155.315      2.103      0.037      19.861     633.267
# ...

# %%
def predicts_Calories(Pulse):
    return 0.4572 * Pulse + 326.5641

print(predicts_Calories(120))
print(predicts_Calories(130))
print(predicts_Calories(150))
print(predicts_Calories(180))
